# %%
from huggingface_hub import notebook_login

notebook_login()
# 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

# %%
from huggingface_hub import snapshot_download

snapshot_download(repo_id="meta-llama/Llama-2-7b-chat-hf", cache_dir="/Users/praneshjayasundar/Documents/Gunner/Boston-University/Fall-2023/student/CS505/final-project/health-assistant/huggingface-models/snapshot-model-hf")
# Out:
# README.md: 100%|██████████| 10.5k/10.5k [00:00<00:00, 30.4MB/s]
#
# .gitattributes: 100%|██████████| 1.52k/1.52k [00:00<00:00, 389kB/s]
# USE_POLICY.md: 100%|██████████| 4.77k/4.77k [00:00<00:00, 2.48MB/s]
# config.json: 100%|██████████| 614/614 [00:00<00:00, 250kB/s]it/s]
# LICENSE.txt: 100%|██████████| 7.02k/7.02k [00:00<00:00, 22.9MB/s]
# generation_config.json: 100%|██████████| 188/188 [00:00<00:00, 1.34MB/s]
# model.safetensors.index.json: 100%|██████████| 26.8k/26.8k [00:00<00:00, 39.2MB/s]
# pytorch_model.bin.index.json: 100%|██████████| 26.8k/26.8k [00:00<00:00, 27.3MB/s]
#
#
#
#
#
#
# special_tokens_map.json: 100%|██████████| 414/414 [00:00<00:00, 3.00MB/s]
#
#
#
# tokenizer_config.json: 100%|██████████| 1.62k/1.62k [00:00<00:00, 11.2MB/s]
#
#
# tokenizer.json: 100%|██████████| 1.84M/1.84M [00:00<00:00, 12.3MB/s]
#
#
#
#
#
#
#
#
#
#
#
# tokenizer.model: 100%|██████████| 500k/500k [00:00<00:00, 3.42MB/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ...

# %%
from huggingface_hub import snapshot_download

snapshot_download(repo_id="praneshgunner/llama2-trained-medical-v2", cache_dir="/Users/praneshjayasundar/Documents/Gunner/Boston-University/Fall-2023/student/CS505/final-project/health-assistant/huggingface-models/snapshot-model-hf")
# Out:
# Fetching 9 files:   0%|          | 0/9 [00:00<?, ?it/s]
# pytorch_model-00001-of-00002.bin:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# pytorch_model-00002-of-00002.bin:   0%|          | 0.00/3.50G [00:00<?, ?B/s]
# '/Users/praneshjayasundar/Documents/Gunner/Boston-University/Fall-2023/student/CS505/final-project/health-assistant/huggingface-models/snapshot-model-hf/models--praneshgunner--llama2-trained-medical-v2/snapshots/b7a3229f1e13ba25679c6e9d1db3b195c5f99173'

# %%
from huggingface_hub import snapshot_download
model_id="praneshgunner/llama2-trained-medical-v2"
snapshot_download(repo_id=model_id, local_dir="/Users/praneshjayasundar/Documents/Gunner/Boston-University/Fall-2023/student/CS505/final-project/health-assistant/huggingface-models/llama-medical-hf", local_dir_use_symlinks=False, revision="main")
# Out:
# Fetching 9 files:   0%|          | 0/9 [00:00<?, ?it/s]
# .gitattributes:   0%|          | 0.00/1.52k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/760 [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/188 [00:00<?, ?B/s]
# pytorch_model.bin.index.json:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/437 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# pytorch_model-00002-of-00002.bin:   0%|          | 0.00/3.50G [00:00<?, ?B/s]
# pytorch_model-00001-of-00002.bin:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.57k [00:00<?, ?B/s]
# '/Users/praneshjayasundar/Documents/Gunner/Boston-University/Fall-2023/student/CS505/final-project/health-assistant/huggingface-models/llama-medical-hf'

# %%
# python llama.cpp/convert.py /Users/praneshjayasundar/Documents/Gunner/Boston-University/Fall-2023/student/CS505/final-project/health-assistant/huggingface-models/llama-medical-hf \
#   --outfile /Users/praneshjayasundar/Documents/Gunner/Boston-University/Fall-2023/student/CS505/final-project/health-assistant/huggingface-models/llama-2-7b-medical.gguf \
#   --outtype q8_0
