# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from huggingface_hub import snapshot_download
model_id="praneshgunner/llama2-trained-medical-v2"
snapshot_download(repo_id=model_id, local_dir="/content/drive/MyDrive/CS505-NLP/Final-Project/snapshot-model-hf/llama-2-medical-hf", local_dir_use_symlinks=False, revision="main")
# Out:
# Fetching 9 files:   0%|          | 0/9 [00:00<?, ?it/s]
# .gitattributes:   0%|          | 0.00/1.52k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/437 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/760 [00:00<?, ?B/s]
# pytorch_model.bin.index.json:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.57k [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/188 [00:00<?, ?B/s]
# pytorch_model-00001-of-00002.bin:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# pytorch_model-00002-of-00002.bin:   0%|          | 0.00/3.50G [00:00<?, ?B/s]
# '/content/drive/MyDrive/CS505-NLP/Final-Project/snapshot-model-hf/llama-2-medical-hf'

# %%
# %cd /content/drive/MyDrive/CS505-NLP/Final-Project
# Out:
# /content/drive/MyDrive/CS505-NLP/Final-Project

# %%
# !pwd
# Out:
# /content/drive/MyDrive/CS505-NLP/Final-Project

# %%
# !git clone https://github.com/ggerganov/llama.cpp.git
# Out:
# Cloning into 'llama.cpp'...
# remote: Enumerating objects: 13878, done.
# remote: Counting objects: 100% (4336/4336), done.
# remote: Compressing objects: 100% (486/486), done.
# remote: Total 13878 (delta 4100), reused 3940 (delta 3846), pack-reused 9542
# Receiving objects: 100% (13878/13878), 15.93 MiB | 20.67 MiB/s, done.
# Resolving deltas: 100% (9671/9671), done.

# %%
# !pip install -r llama.cpp/requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 58.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 76.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.6/294.6 kB 34.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.23.5
#     Uninstalling numpy-1.23.5:
#       Successfully uninstalled numpy-1.23.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires fastapi, which is not installed.
# lida 0.0.10 requires kaleido, which is not installed.
# lida 0.0.10 requires python-multipart, which is not installed.
# lida 0.0.10 requires uvicorn, which is not installed.
# ...

# %%
# !pip install fastapi
# !pip install kaleido
# !pip install python-multipart
# !pip install uvicorn
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.1/93.1 kB 1.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 kB 5.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.5.0
#     Uninstalling typing_extensions-4.5.0:
#       Successfully uninstalled typing_extensions-4.5.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires kaleido, which is not installed.
# lida 0.0.10 requires python-multipart, which is not installed.
# lida 0.0.10 requires uvicorn, which is not installed.
# tensorflow-probability 0.22.0 requires typing-extensions<4.6.0, but you have typing-extensions 4.9.0 which is incompatible.
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 9.6 MB/s eta 0:00:00
# ...

# %%
# !python llama.cpp/convert.py -h
# Out:
# usage: convert.py [-h] [--dump] [--dump-single] [--vocab-only] [--outtype {f32,f16,q8_0}]
#                   [--vocab-dir VOCAB_DIR] [--outfile OUTFILE] [--ctx CTX]
#                   [--concurrency CONCURRENCY] [--bigendian] [--padvocab]
#                   model
#
# Convert a LLaMa model to a GGML compatible file
#
# positional arguments:
#   model                 directory containing model file, or model file itself (*.pth, *.pt, *.bin)
#
# options:
#   -h, --help            show this help message and exit
#   --dump                don't convert, just show what's in the model
#   --dump-single         don't convert, just show what's in a single model file
#   --vocab-only          extract only the vocab
#   --outtype {f32,f16,q8_0}
#                         output format - note: q8_0 may be very slow (default: f16 or f32 based on
#                         input)
#   --vocab-dir VOCAB_DIR
#                         directory containing tokenizer.model, if separate from model file
# ...

# %%
# !python llama.cpp/convert.py /content/drive/MyDrive/CS505-NLP/Final-Project/snapshot-model-hf/llama-2-medical-hf \
  --outfile /content/drive/MyDrive/CS505-NLP/Final-Project/snapshot-model-hf/llama-2-medical-hf/llama-2-7B-chat-medical-v2.gguf \
  --outtype q4_0
# Out:
# usage: convert.py [-h] [--dump] [--dump-single] [--vocab-only] [--outtype {f32,f16,q8_0}]
#                   [--vocab-dir VOCAB_DIR] [--outfile OUTFILE] [--ctx CTX]
#                   [--concurrency CONCURRENCY] [--bigendian] [--padvocab]
#                   model
# convert.py: error: argument --outtype: invalid choice: 'q4_0' (choose from 'f32', 'f16', 'q8_0')

# %%
from huggingface_hub import notebook_login

notebook_login()

# %%
from huggingface_hub import HfApi
api = HfApi()

model_id = "praneshgunner/llama-2-7b-chat-medical-gguf"
api.create_repo(model_id, exist_ok=True, repo_type="model")
api.upload_file(
    path_or_fileobj="/content/drive/MyDrive/CS505-NLP/Final-Project/snapshot-model-hf/llama-2-medical-hf/llama-2-7B-chat-medical-v2.gguf",
    path_in_repo="llama-2-7b-chat-medical-gguf",
    repo_id=model_id,
)
# Out:
# llama-2-7B-chat-medical-v2.gguf:   0%|          | 0.00/7.16G [00:00<?, ?B/s]
# 'https://huggingface.co/praneshgunner/llama-2-7b-chat-medical-gguf/blob/main/llama-2-7b-chat-medical-gguf'

# %% [markdown]
# ## Push GPT2 fined tuned to huggingface

# %%
from huggingface_hub import HfApi
api = HfApi()

model_id = "praneshgunner/gpt2-medical-v1"
api.create_repo(model_id, exist_ok=True, repo_type="model")
api.upload_file(
    path_or_fileobj="/content/drive/MyDrive/CS505-NLP/Final-Project/snapshot-model-hf/llama-2-medical-hf/llama-2-7B-chat-medical-v2.gguf",
    path_in_repo="llama-2-7b-chat-medical-gguf",
    repo_id=model_id,
)
